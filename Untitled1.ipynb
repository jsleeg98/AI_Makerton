# %%
# %pwd
# Out:
# '/home/twopiece/src'

# %%
# %cd yolov5
# Out:
# /home/twopiece/src/yolov5

# %%
# !python val.py --weights yolov5x.pt --iou-thres 0.5 --data /home/twopiece/datasets_rw/dataset/AI_dataset/data.yaml --save-txt --name txt_test --batch-size 16
# Out:
# val: data=/home/twopiece/datasets_rw/dataset/AI_dataset/data.yaml, weights=['yolov5x.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.5, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=txt_test, exist_ok=False, half=False
# YOLOv5 🚀 v5.0-499-g48b00db torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# val: Scanning '/home/twopiece/datasets_rw/dataset/AI_dataset/val.cache' images a
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# Traceback (most recent call last):
#   File "val.py", line 358, in <module>
#     main(opt)
#   File "val.py", line 333, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py", line 26, in decorate_context
#     return func(*args, **kwargs)
# ...

# %%
import val

data_dict{'val' : '/home/twopiece/datasets_rw/dataset/AI_dataset/val.txt',
          'train' : '/home/twopiece/datasets_rw/dataset/AI_dataset/train.txt',
          'nc' : 2,
          'names' : ['helmat', 'head']
         }

val.run(data_dict,
       batch_size = 32,
       )

# %%
# !python detect.py --source /home/twopiece/datasets_rw/dataset/AI_dataset/images --weight /home/twopiece/src/yolov5/runs/train/helmat_yolov5x_result/weights/best.pt  --img 416 --iou-thres 0.5 --save-txt --save-conf --name txt_test
# Out:
# detect: weights=['/home/twopiece/src/yolov5/runs/train/helmat_yolov5x_result/weights/best.pt'], source=/home/twopiece/datasets_rw/dataset/AI_dataset/images, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=txt_test, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-499-g48b00db torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87205423 parameters, 0 gradients, 217.1 GFLOPs
# image 1/5000 /home/twopiece/datasets_rw/dataset/AI_dataset/images/hard_hat_workers0.png: 416x416 8 helmats, 5 heads, Done. (0.035s)
# image 2/5000 /home/twopiece/datasets_rw/dataset/AI_dataset/images/hard_hat_workers1.png: 416x416 9 helmats, Done. (0.035s)
# ...
