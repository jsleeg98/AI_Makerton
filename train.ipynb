# %% [markdown]
# # 학습 코드 실행 방법

# %% [markdown]
# ## 현재 위치 확인

# %%
# %pwd

# %% [markdown]
# ## yolov5 로 위치 변경

# %%
# %cd yolov5
# Out:
# /home/twopiece/src/yolov5

# %% [markdown]
# !pip list

# %% [markdown]
# !pip install -r ./requirements.txt

# %% [markdown]
# # path 설정

# %% [markdown]
# ### 이 때 데이터가 있는 폴더로 위치로 path를 바꿔주어야한다.
# ### path 폴더 안에는 이미지가 들어있는 images 폴더와 txt로 라벨링이 들어있는 labels 폴더와 data.yaml 파일이 있어야한다.

# %%
path = '/home/twopiece/datasets_rw/final-dataset/'

from glob import glob

img_list = glob(path + 'images/*.png')

print(len(img_list))

from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size = 0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))

with open(path + 'train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open(path + 'val.txt','w') as f:
    f.write('\n'.join(val_img_list)+ '\n')

import yaml

with open(path + 'data.yaml', 'r') as f:
    data = yaml.load(f)
    
print(data)

data['train'] = path + 'train.txt'
data['val'] = path + 'val.txt'

with open(path + 'data.yaml', 'w') as f:
    yaml.dump(data,f)

print(data)
# Out:
# 4883
# 3906 977
# {'names': ['helmat', 'head'], 'nc': 2, 'train': '/home/twopiece/dataset/train.txt', 'val': '/home/twopiece/dataset/val.txt'}
# {'names': ['helmat', 'head'], 'nc': 2, 'train': '/home/twopiece/datasets_rw/final-dataset/train.txt', 'val': '/home/twopiece/datasets_rw/final-dataset/val.txt'}
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %% [markdown]
# ## 패키지 설치 필요(참고)

# %%
# !sudo apt install libgl1-mesa-glx -y

# %% [markdown]
# ## 학습 실행 코드
# ### epoch과 data와 pretrained된 모델을 설정해준다.
#
# -> yolov5/runs/train/result 폴더에 학습 결과가 저장된다.
#
# -> 학습된 가중치는 yolov5/runs/train/result/weights에 저장된다.

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data /home/twopiece/datasets_rw/final-dataset/data.yaml --weights yolov5x.pt
# Out:
# train: weights=yolov5x.pt, cfg=, data=/home/twopiece/datasets_rw/final-dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=result_yolov5x, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-507-g4cf7d48 torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data /home/twopiece/datasets_rw/final-dataset/data.yaml --weights yolov5x6.pt
# Out:
# train: weights=yolov5x6.pt, cfg=, data=/home/twopiece/datasets_rw/final-dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=result, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-507-g4cf7d48 torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data /home/twopiece/datasets_rw/final-dataset/data.yaml --weights ./runs/train/result2/weights/last.pt
# Out:
# train: weights=./runs/train/result2/weights/last.pt, cfg=, data=/home/twopiece/datasets_rw/final-dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=result, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-507-g4cf7d48 torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# ...
