# %%
# %pwd
# Out:
# '/home/twopiece/src/yolov5'

# %% [markdown]
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# /home/twopiece/src/yolov5

# %% [markdown]
# !pip list

# %% [markdown]
# !pip install -r ./requirements.txt

# %% [markdown]
# # path 설정

# %%
path = '/home/twopiece/datasets_rw/final-dataset/'

from glob import glob

img_list = glob(path + 'images/*.png')

print(len(img_list))

from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size = 0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))

with open(path + 'train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')
    
with open(path + 'val.txt','w') as f:
    f.write('\n'.join(val_img_list)+ '\n')

import yaml

with open(path + 'data.yaml', 'r') as f:
    data = yaml.load(f)
    
print(data)

data['train'] = path + 'train.txt'
data['val'] = path + 'val.txt'

with open(path + 'data.yaml', 'w') as f:
    yaml.dump(data,f)

print(data)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5bcd943978ed> in <module>
#       9 from sklearn.model_selection import train_test_split
#      10
# ---> 11 train_img_list, val_img_list = train_test_split(img_list, test_size = 0.2, random_state=2000)
#      12
#      13 print(len(train_img_list), len(val_img_list))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2174     n_samples = _num_samples(arrays[0])
#    2175     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2176                                               default_test_size=0.25)
#    2177
#    2178     if shuffle is False:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1859             'resulting train set will be empty. Adjust any of the '
#    1860             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1861                                                 train_size)
#    1862         )
#    1863
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %% [markdown]
# ## 패키지 설치 필요

# %% [markdown]
# !sudo apt install libgl1-mesa-glx -y

# %%
# !python train.py --img 416 --batch 8 --epoch 300 --data /home/twopiece/datasets_rw/new-dataset/new_dataset/data.yaml --cfg ./models/yolov5x.yaml --weights yolov5x.pt --name yolov5x_result
# Out:
# train: weights=yolov5x.pt, cfg=./models/yolov5x.yaml, data=/home/twopiece/datasets_rw/new-dataset/new_dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=8, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=yolov5x_result, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-499-g48b00db torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1 12   3285760  models.common.C3                        [320, 320, 12]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  1   4099840  models.common.SPP                       [1280, 1280, [5, 9, 13]]
#   9                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     47103  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model Summary: 607 layers, 87251103 parameters, 87251103 gradients, 217.3 GFLOPs
#
# Transferred 786/794 items from yolov5x.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 131 weight, 134 weight (no decay), 134 bias
# train: Scanning '/home/twopiece/datasets_rw/new-dataset/new_dataset/train.cache'
# val: Scanning '/home/twopiece/datasets_rw/new-dataset/new_dataset/val.cache' ima
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.83, Best Possible Recall (BPR) = 0.9997
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/train/yolov5x_result6
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   0%|                                                   | 0/342 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 624, in <module>
#     main(opt)
#   File "train.py", line 521, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "train.py", line 318, in train
#     pred = model(imgs)  # forward
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/twopiece/src/yolov5/models/yolo.py", line 124, in forward
#     return self._forward_once(x, profile, visualize)  # single-scale inference, train
#   File "/home/twopiece/src/yolov5/models/yolo.py", line 147, in _forward_once
#     x = m(x)  # run
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/twopiece/src/yolov5/models/common.py", line 137, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), dim=1))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py", line 117, in forward
#     input = module(input)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/twopiece/src/yolov5/models/common.py", line 103, in forward
#     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/twopiece/src/yolov5/models/common.py", line 45, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py", line 423, in forward
#     return self._conv_forward(input, self.weight)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py", line 420, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Unable to find a valid cuDNN algorithm to run convolution

# %%
# !python train.py --img 416 --batch 16 --epochs 100 --data /home/twopiece/datasets_rw/final-dataset/data.yaml --weights yolov5x.pt --name result_yolov5x
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /home/twopiece/.config/Ultralytics/Arial.ttf...
# train: weights=yolov5x.pt, cfg=, data=/home/twopiece/datasets_rw/new-dataset/new_dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=result_yolov5, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-507-g4cf7d48 torch 1.7.1+cu110 CUDA:0 (A100-SXM4-40GB MIG 2g.10gb, 9984.0MB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-10-11 10:35:52.381869: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.11.0
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100%|████████████████████████████████████████| 168M/168M [00:05<00:00, 35.0MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1 12   3285760  models.common.C3                        [320, 320, 12]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  1   4099840  models.common.SPP                       [1280, 1280, [5, 9, 13]]
#   9                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     47103  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model Summary: 607 layers, 87251103 parameters, 87251103 gradients, 217.3 GFLOPs
#
# Transferred 788/794 items from yolov5x.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 131 weight, 134 weight (no decay), 134 bias
# train: Scanning '/home/twopiece/datasets_rw/new-dataset/new_dataset/train.cache'
# val: Scanning '/home/twopiece/datasets_rw/new-dataset/new_dataset/val.cache' ima
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.83, Best Possible Recall (BPR) = 0.9997
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/train/result_yolov5
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/299     7.29G    0.0838   0.03239   0.01365        58       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404       0.68      0.291      0.205     0.0499
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/299     8.19G   0.05987   0.02291  0.007466        39       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.814      0.362       0.39       0.14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/299     8.19G    0.0504   0.02028  0.006576        50       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.896      0.409       0.52      0.219
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/299     8.19G   0.05032   0.01898  0.006547        74       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.404      0.783       0.57       0.29
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/299     8.19G    0.0458   0.01875  0.006287        35       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.351      0.838       0.56      0.231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/299     8.19G    0.0452   0.01896  0.005431        35       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.458      0.758      0.573      0.278
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/299     8.19G   0.04122   0.01889  0.005244        50       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.447      0.793      0.602      0.321
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/299     8.19G   0.03898   0.01822  0.005081        34       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.517      0.884      0.592      0.317
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/299     8.19G   0.03718   0.01756  0.004357        70       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.513      0.884      0.597      0.322
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/299     8.19G   0.03665   0.01766  0.004833        56       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.509      0.848      0.597      0.336
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/299     8.19G   0.03516   0.01733   0.00472        68       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.522       0.85      0.589      0.319
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/299     8.19G   0.03478   0.01689   0.00428        47       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.488      0.849      0.593       0.33
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/299     8.19G   0.03386   0.01652  0.004076        35       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.513      0.867      0.602      0.345
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/299     8.19G   0.03275   0.01599   0.00404        43       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.509      0.799      0.592       0.34
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/299     8.19G    0.0324    0.0162  0.004061        50       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.476      0.733      0.571      0.345
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/299     8.19G   0.03196   0.01605  0.003919        59       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.542      0.886      0.608      0.366
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/299     8.19G   0.03157   0.01586  0.004142        36       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.527      0.866      0.602      0.363
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/299     8.19G   0.03031   0.01574  0.003798        69       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.506      0.796      0.581      0.371
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/299     8.19G   0.03024   0.01543  0.003978        55       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.499      0.754      0.556      0.342
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/299     8.19G    0.0294   0.01555   0.00365        52       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.535      0.892      0.602      0.378
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/299     8.19G   0.02944   0.01501     0.004        74       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.537      0.862      0.596      0.372
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/299     8.19G   0.02855    0.0145  0.003786        21       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.546      0.879      0.601      0.368
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/299     8.19G   0.02865    0.0152  0.003643        66       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.503      0.866      0.584      0.378
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/299     8.19G   0.02853   0.01442  0.003912        47       416: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        684       2404      0.549      0.869      0.605      0.381
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/299